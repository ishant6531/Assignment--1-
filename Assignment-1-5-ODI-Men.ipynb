# %%
# Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:
# i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# ii) Top 10 ODI Batsmen in men along with the records of their team and rating.
# iii) Top 10 ODI bowlers along with the records of their team and rating.

# %%
#importing  the required librares
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Now we will send the request to the webpage server to get the source code of the page which is to be scraped by using the request library

page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")

# %%
# Let's see show the webpage source code downloaded 
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta proper
# ...

# %%
# Now we will parse this source code by using BeautifulSoup and the parser used here is html.parser as the source code is the HTML.
soup=BeautifulSoup(page.content,'html.parser')

# %%
#Lets see how our parsed structure look like and we will use prettify function to present tit in more understandable and readable format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# ...

# %%
Name = []
Matches = []
Match1 = []
Match2= []
Points = []
Point1 = []
Rating = []
Rating1= []

# %%
name = soup.find_all('span', class_="u-hide-phablet")

# %%
# Getting Team Name
for i in name:
    Name.append(i.get_text())
Name[0:5]
# Out:
# ['England', 'India', 'New Zealand', 'Australia', 'South Africa']

# %%
name=pd.DataFrame(Name)

# %%
name=name.iloc[0:10]

# %%
name=name.rename({0: 'Team'}, axis=1)

# %%
match1=soup.find_all('td', class_ ='rankings-block__banner--matches')
match1
# Out:
# [<td class="rankings-block__banner--matches">44</td>]

# %%
for i in match1:
    Match1.append(i.get_text())
Match1
# Out:
# ['44']

# %%
df1=pd.DataFrame(Match1)
df1= df1.rename({0 : 'Matches'}, axis=1)
df1
# Out:
#   Matches
# 0      44

# %%
point1=soup.find_all('td', class_ ='rankings-block__banner--points')
point1
# Out:
# [<td class="rankings-block__banner--points">5,405</td>]

# %%
for i in point1:
    Point1.append(i.get_text())
Point1
# Out:
# ['5,405']

# %%
df2=pd.DataFrame(Point1)
df2=df2.rename({0 : 'Points'},axis=1)
df2
# Out:
#   Points
# 0  5,405

# %%
rating1= soup.find_all('td', class_ = 'rankings-block__banner--rating u-text-right')
rating1
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                              123
#                              <span class="circle-branding circle-branding--top"></span>
#  <span class="circle-branding circle-branding--bottom"></span>
#  </td>]

# %%
for i in rating1:
    Rating1.append(i.get_text())
Rating1
# Out:
# ['\n                            123\n                            \n\n']

# %%
Rating1=pd.DataFrame(Rating1)

# %%
Rating1
# Out:
#                                                    0
# 0  \n                            123\n           ...

# %%
Rating1 =Rating1[0].str.split('\n').str[1]

# %%
Rating2=pd.DataFrame(Rating1)

# %%
Rating2
# Out:
#                                  0
# 0                              123

# %%
df3=pd.DataFrame(Rating2)
df3= df3.rename({0 : 'Rating'},axis=1)
df3
# Out:
#                             Rating
# 0                              123

# %%
Aus=pd.concat([df1,df2,df3],axis=1)
Aus
# Out:
#   Matches Points                           Rating
# 0      44  5,405                              123

# %%
matches2 =soup.find_all('td', class_='table-body__cell u-center-text')
matches2[0:5]
# Out:
# [<td class="table-body__cell u-center-text">49</td>,
#  <td class="table-body__cell u-center-text">5,819</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,716</td>,
#  <td class="table-body__cell u-center-text">36</td>]

# %%
for i in matches2:
    Match2.append(i.get_text())
Match2[0:5]
# Out:
# ['49', '5,819', '32', '3,716', '36']

# %%
df4=pd.DataFrame(Match2)
df4[0:5]
# Out:
#        0
# 0     49
# 1  5,819
# 2     32
# 3  3,716
# 4     36

# %%
df5 =df4.iloc[0:37:2]
df5.index= range(19)
df5=df5.rename({0: 'Matches'},axis=1)
df5=df5.iloc[0:9]

# %%
df5
# Out:
#   Matches
# 0      49
# 1      32
# 2      36
# 3      31
# 4      32
# 5      34
# 6      39
# 7      43
# 8      28

# %%
# Getting Points of differnt Teams,
df6=df4.iloc[1:18:2]
df6.index=range(9)
df6=df6.rename({0 : 'Points'},axis=1)

# %%
df6
# Out:
#   Points
# 0  5,819
# 1  3,716
# 2  3,941
# 3  3,345
# 4  3,254
# 5  2,989
# 6  3,297
# 7  3,285
# 8  1,549

# %%
rating2=soup.find_all('td', class_ = "table-body__cell u-text-right rating")
rating2[0:4]
# Out:
# [<td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">116</td>,
#  <td class="table-body__cell u-text-right rating">109</td>,
#  <td class="table-body__cell u-text-right rating">108</td>]

# %%
#Getting Rating of different Teams
for i  in rating2:
    Rating.append(i.get_text())
Rating[0:4]
# Out:
# ['119', '116', '109', '108']

# %%
Rating=pd.DataFrame(Rating)
df7=Rating.iloc[0:9]

# %%
df7
# Out:
#      0
# 0  119
# 1  116
# 2  109
# 3  108
# 4  102
# 5   88
# 6   85
# 7   76
# 8   55

# %%
df7=df7.rename({0:"Rating"}, axis=1)

# %%
df7
# Out:
#   Rating
# 0    119
# 1    116
# 2    109
# 3    108
# 4    102
# 5     88
# 6     85
# 7     76
# 8     55

# %%
ODI2 =pd.concat([df5,df6 ,df7], axis=1)

# %%
ODI2
# Out:
#   Matches Points Rating
# 0      49  5,819    119
# 1      32  3,716    116
# 2      36  3,941    109
# 3      31  3,345    108
# 4      32  3,254    102
# 5      34  2,989     88
# 6      39  3,297     85
# 7      43  3,285     76
# 8      28  1,549     55

# %%
ODI2 =pd.concat([Aus,ODI2] , axis=0)

# %%
ODI2.index=range(10)

# %%
ODI2
# Out:
#   Matches Points                           Rating
# 0      44  5,405                              123
# 1      49  5,819                              119
# 2      32  3,716                              116
# 3      36  3,941                              109
# 4      31  3,345                              108
# 5      32  3,254                              102
# 6      34  2,989                               88
# 7      39  3,297                               85
# 8      43  3,285                               76
# 9      28  1,549                               55

# %% [markdown]
# # Top Ten ODI Men  Team

# %%
ODI=pd.concat([name,ODI2], axis=1)
ODI
# Out:
#            Team Matches Points                           Rating
# 0       England      44  5,405                              123
# 1         India      49  5,819                              119
# 2   New Zealand      32  3,716                              116
# 3     Australia      36  3,941                              109
# 4  South Africa      31  3,345                              108
# 5      Pakistan      32  3,254                              102
# 6    Bangladesh      34  2,989                               88
# 7     Sri Lanka      39  3,297                               85
# 8   West Indies      43  3,285                               76
# 9   Afghanistan      28  1,549                               55

# %% [markdown]
# # Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
# Now we will send the request to the webpage server to get the source code of the page which is to be scraped by using the request library

page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")

# %%
# Let's see show the webpage source code downloaded 
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:image" content=
# ...

# %%
# Now we will parse this source code by using BeautifulSoup and the parser used here is html.parser as the source code is the HTML.
soup=BeautifulSoup(page.content,'html.parser')

# %%
#Lets see how our parsed structure look like and we will use prettify function to present tit in more understandable and readable format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
Player =[]
Player1=[]
Team = []
Team1=[]
Rating =[]
Rating1=[]

# %%
player=soup.find_all('div', class_='rankings-block__banner--name')
player
# Out:
# [<div class="rankings-block__banner--name">Virat Kohli</div>,
#  <div class="rankings-block__banner--name">Trent Boult</div>,
#  <div class="rankings-block__banner--name">Mohammad Nabi</div>,
#  <div class="rankings-block__banner--name">Virat Kohli</div>,
#  <div class="rankings-block__banner--name">Trent Boult</div>,
#  <div class="rankings-block__banner--name">Mohammad Nabi</div>]

# %%
for i in player:
    Player1.append( i.get_text())
Player1
# Out:
# ['Virat Kohli',
#  'Trent Boult',
#  'Mohammad Nabi',
#  'Virat Kohli',
#  'Trent Boult',
#  'Mohammad Nabi']

# %%
# Getting Players Name
df8=pd.DataFrame(Player1)
df8=df8.rename( columns= { 0 : 'Player Name'})

# %%
df8
# Out:
#      Player Name
# 0    Virat Kohli
# 1    Trent Boult
# 2  Mohammad Nabi
# 3    Virat Kohli
# 4    Trent Boult
# 5  Mohammad Nabi

# %%
df9=df8.iloc[[0],[0]]
df9
# Out:
#    Player Name
# 0  Virat Kohli

# %%
df10=df8.iloc[[1],[0]]
df10
# Out:
#    Player Name
# 1  Trent Boult

# %%
team1=soup.find_all('div', class_='rankings-block__banner--nationality')
team1
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 IND"></div>
#  <span class="rankings-block__banner--nation"></span>IND</div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 NZ"></div>
#  <span class="rankings-block__banner--nation"></span>NZ</div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 AFG"></div>
#  <span class="rankings-block__banner--nation"></span>AFG</div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 IND"></div>
#  <span class="rankings-block__banner--nation"></span>IND</div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 NZ"></div>
#  <span class="rankings-block__banner--nation"></span>NZ</div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 AFG"></div>
#  <span class="rankings-block__banner--nation"></span>AFG</div>]

# %%
for i in team1:
    Team1.append( i.get_text())
Team1
# Out:
# ['\n\nIND', '\n\nNZ', '\n\nAFG', '\n\nIND', '\n\nNZ', '\n\nAFG']

# %%
df11=pd.DataFrame(Team1)

# %%
df11
# Out:
#          0
# 0  \n\nIND
# 1   \n\nNZ
# 2  \n\nAFG
# 3  \n\nIND
# 4   \n\nNZ
# 5  \n\nAFG

# %%
df11[0] =df11[0].str.replace('\n',' ')

# %%
df11=df11.rename({0 : 'Team'}, axis=1)

# %%
#Getting Team Name
df11
# Out:
#     Team
# 0    IND
# 1     NZ
# 2    AFG
# 3    IND
# 4     NZ
# 5    AFG

# %%
df9
# Out:
#    Player Name
# 0  Virat Kohli

# %%
df12=df11.iloc[[0],[0]]
df13=df11.iloc[[1],[0]]

# %%
df12
# Out:
#     Team
# 0    IND

# %%
df13
# Out:
#    Team
# 1    NZ

# %%
rating1=soup.find_all('div' , class_ ='rankings-block__banner--rating')
rating1
# Out:
# [<div class="rankings-block__banner--rating">871</div>,
#  <div class="rankings-block__banner--rating">722</div>,
#  <div class="rankings-block__banner--rating">301</div>,
#  <div class="rankings-block__banner--rating">871</div>,
#  <div class="rankings-block__banner--rating">722</div>,
#  <div class="rankings-block__banner--rating">301</div>]

# %%
for d in rating1:
    Rating1.append(d.get_text())
Rating1
# Out:
# ['871', '722', '301', '871', '722', '301']

# %%
Rating1=pd.DataFrame(Rating1)

# %%
Rating1=Rating1.rename({0: 'Rating'}, axis=1)

# %%
Rating1
# Out:
#   Rating
# 0    871
# 1    722
# 2    301
# 3    871
# 4    722
# 5    301

# %%
df14=Rating1.iloc[[0],[0]]
df15=Rating1.iloc[[1],[0]]

# %%
df15
# Out:
#   Rating
# 1    722

# %%
df16=pd.concat([df9,df12,df14], axis=1)
df16
# Out:
#    Player Name   Team Rating
# 0  Virat Kohli    IND    871

# %%
df17=pd.concat([df10,df13,df15] , axis=1)
df17
# Out:
#    Player Name  Team Rating
# 1  Trent Boult    NZ    722

# %%
name= soup.find_all('td', class_ ='table-body__cell name')
name[0:5]
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/2759">Babar Azam</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/440">Kane Williamson</a>
#  </td>]

# %%
for i in name:
    Player.append(i.get_text())
Player[0:4]
# Out:
# ['\nRohit Sharma\n',
#  '\nBabar Azam\n',
#  '\nRoss Taylor\n',
#  '\nFrancois du Plessis\n']

# %%
df18=pd.DataFrame(Player)
df18=df18.rename( columns={0 : 'Player Name'})

# %%
df18['Player Name']=df18['Player Name'].str.split('\n').str[1]

# %%
df19=df18.iloc[0:10]
df19[0:5]
# Out:
#            Player Name
# 0         Rohit Sharma
# 1           Babar Azam
# 2          Ross Taylor
# 3  Francois du Plessis
# 4      Kane Williamson

# %%
team=soup.find_all('span',class_='table-body__logo-text')
team[0:5]
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
Team1
# Out:
# ['\n\nIND', '\n\nNZ', '\n\nAFG', '\n\nIND', '\n\nNZ', '\n\nAFG']

# %%
for i in team:
    Team1.append(i.get_text())
Team1=pd.DataFrame(Team1)
Team1[0:5]
# Out:
#          0
# 0  \n\nIND
# 1   \n\nNZ
# 2  \n\nAFG
# 3  \n\nIND
# 4   \n\nNZ

# %%
Team2=Team1.iloc[6:16]

# %%
Team2.index=range(10)
Team2=Team2.rename({0 : 'Team'}, axis=1)
Team2
# Out:
#   Team
# 0  IND
# 1  PAK
# 2   NZ
# 3   SA
# 4   NZ
# 5  AUS
# 6  AUS
# 7   SA
# 8  ENG
# 9  IND

# %%
rat=soup.find_all('td', class_= 'table-body__cell u-text-right rating')
rat[0:5]
# Out:
# [<td class="table-body__cell u-text-right rating">855</td>,
#  <td class="table-body__cell u-text-right rating">829</td>,
#  <td class="table-body__cell u-text-right rating">818</td>,
#  <td class="table-body__cell u-text-right rating">790</td>,
#  <td class="table-body__cell u-text-right rating">765</td>]

# %%
for i in rat:
    Rating.append(i.get_text())
Rating=pd.DataFrame(Rating)
Rating=Rating.rename({0:'Rating'}, axis=1)
Rating=Rating.iloc[0:10]

# %%
Rating
# Out:
#   Rating
# 0    855
# 1    829
# 2    818
# 3    790
# 4    765
# 5    762
# 6    759
# 7    755
# 8    754
# 9    719

# %%
df20=pd.concat([df19,Team2,Rating], axis=1)

# %%
df20
# Out:
#            Player Name Team Rating
# 0         Rohit Sharma  IND    855
# 1           Babar Azam  PAK    829
# 2          Ross Taylor   NZ    818
# 3  Francois du Plessis   SA    790
# 4      Kane Williamson   NZ    765
# 5          Aaron Finch  AUS    762
# 6         David Warner  AUS    759
# 7      Quinton de Kock   SA    755
# 8       Jonny Bairstow  ENG    754
# 9       Jasprit Bumrah  IND    719

# %%
df16
# Out:
#    Player Name   Team Rating
# 0  Virat Kohli    IND    871

# %%
ODI_Player=pd.concat([df16,df20], axis=0)

# %% [markdown]
# # Top Ten ODI Batsmen Table

# %%
ODI_Player.index=range(11)
ODI_Player
# Out:
#             Player Name   Team Rating
# 0           Virat Kohli    IND    871
# 1          Rohit Sharma    IND    855
# 2            Babar Azam    PAK    829
# 3           Ross Taylor     NZ    818
# 4   Francois du Plessis     SA    790
# 5       Kane Williamson     NZ    765
# 6           Aaron Finch    AUS    762
# 7          David Warner    AUS    759
# 8       Quinton de Kock     SA    755
# 9        Jonny Bairstow    ENG    754
# 10       Jasprit Bumrah    IND    719

# %% [markdown]
# # Top 10 ODI bowlers along with the records of their team and rating.

# %%
Bowler=[]
Bowler1=[]
Team=[]
Team1=[]
Rating=[]

# %%
bowler=soup.find_all('td', class_= 'table-body__cell name')
bowler
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/2759">Babar Azam</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/440">Kane Williamson</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>,
#  <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/834">Quinton de Kock</a>
#  </td>,
#  <td class="table-body__cell name">
# ...

# %%
for i in bowler:
    Bowler1.append(i.get_text())
Bowler1=pd.DataFrame(Bowler1)

# %%
Bowler1=Bowler1.iloc[9:18]

# %%
Bowler1[0:5]
# Out:
#                        0
# 9     \nJasprit Bumrah\n
# 10  \nMujeeb Ur Rahman\n
# 11      \nChris Woakes\n
# 12     \nKagiso Rabada\n
# 13       \nPat Cummins\n

# %%
Bowler1=Bowler1.rename(columns= {0 :'Bowler Name'})
Bowler1[0:5]
# Out:
#              Bowler Name
# 9     \nJasprit Bumrah\n
# 10  \nMujeeb Ur Rahman\n
# 11      \nChris Woakes\n
# 12     \nKagiso Rabada\n
# 13       \nPat Cummins\n

# %%
Bowler1[0:5]
# Out:
#              Bowler Name
# 9     \nJasprit Bumrah\n
# 10  \nMujeeb Ur Rahman\n
# 11      \nChris Woakes\n
# 12     \nKagiso Rabada\n
# 13       \nPat Cummins\n

# %%
# Getting Bowler name
Bowler1['Bowler Name'] = Bowler1['Bowler Name'].str.replace('\n',' ')
Bowler1
# Out:
#            Bowler Name
# 9      Jasprit Bumrah
# 10   Mujeeb Ur Rahman
# 11       Chris Woakes
# 12      Kagiso Rabada
# 13        Pat Cummins
# 14      Mohammad Amir
# 15     Josh Hazlewood
# 16         Matt Henry
# 17       Jofra Archer

# %%
team=soup.find_all('span', class_= 'table-body__logo-text')
team[0:5]
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
for i in team:
    Team1.append(i.get_text())
Team1=pd.DataFrame(Team1)

# %%
Team1[0:5]
# Out:
#      0
# 0  IND
# 1  PAK
# 2   NZ
# 3   SA
# 4   NZ

# %%
Team1=Team1.iloc[9:18]
Team1=Team1.rename(columns= {0 :'Team'})

# %%
#Getting Team name
Team1[0:5]
# Out:
#    Team
# 9   IND
# 10  AFG
# 11  ENG
# 12   SA
# 13  AUS

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rating=soup.find_all('td', class_= 'table-body__cell u-text-right rating')
rating[0:5]
# Out:
# [<td class="table-body__cell u-text-right rating">855</td>,
#  <td class="table-body__cell u-text-right rating">829</td>,
#  <td class="table-body__cell u-text-right rating">818</td>,
#  <td class="table-body__cell u-text-right rating">790</td>,
#  <td class="table-body__cell u-text-right rating">765</td>]

# %%
for i in rating:
    Rating.append(i.get_text())
Rating[0:5]
# Out:
# ['855', '829', '818', '790', '765']

# %%
Rating=pd.DataFrame(Rating)
Rating=Rating.iloc[9:18]
Rating[0:5]
# Out:
#       0
# 9   719
# 10  701
# 11  675
# 12  665
# 13  659

# %%
Rating=Rating.rename(columns = {0:'Rating'})
Rating[0:5]
# Out:
#    Rating
# 9     719
# 10    701
# 11    675
# 12    665
# 13    659

# %%
ODI_Bowler=pd.concat([Bowler1,Team1,Rating], axis=1)
ODI_Bowler
# Out:
#            Bowler Name Team Rating
# 9      Jasprit Bumrah   IND    719
# 10   Mujeeb Ur Rahman   AFG    701
# 11       Chris Woakes   ENG    675
# 12      Kagiso Rabada    SA    665
# 13        Pat Cummins   AUS    659
# 14      Mohammad Amir   PAK    657
# 15     Josh Hazlewood   AUS    654
# 16         Matt Henry    NZ    641
# 17       Jofra Archer   ENG    637

# %%
df17=df17.rename(columns = {"Player Name": 'Bowler Name'})

# %%
df17
# Out:
#    Bowler Name  Team Rating
# 1  Trent Boult    NZ    722

# %%
ODI_Bowler=pd.concat([df17,ODI_Bowler], axis=0)

# %% [markdown]
# # TOP Ten  ODI Men Bowler

# %%
ODI_Bowler.index= range(10)
ODI_Bowler
# Out:
#           Bowler Name  Team Rating
# 0         Trent Boult    NZ    722
# 1     Jasprit Bumrah    IND    719
# 2   Mujeeb Ur Rahman    AFG    701
# 3       Chris Woakes    ENG    675
# 4      Kagiso Rabada     SA    665
# 5        Pat Cummins    AUS    659
# 6      Mohammad Amir    PAK    657
# 7     Josh Hazlewood    AUS    654
# 8         Matt Henry     NZ    641
# 9       Jofra Archer    ENG    637
